# %% [markdown]
# ![p1.png](attachment:p1.png)

# %% [markdown]
# ## Python objects and classes

# %%
# create a class
class my_class:# class defined
    x=5# all class members are public by default
classobj=my_class()# classobj is object of class my_class,we use this object to access class objects
# we use obj.attribute to access that attribute
print(classobj.x)
# Out:
# 5

# %%
# we can access attributes and assign values
class m2:
    name=""
    age=0

obj=m2()
obj.name="bill"
obj.age=21
print(f"Name: {obj.name}, age: {obj.age} ")
# Out:
# Name: bill, age: 21

# %% [markdown]
# The self parameter is a reference to the current instance of the class,
# and is used to access variables that belongs to the class.

# %% [markdown]
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
class stu:
    name="hamza"
    rollno=1669
    def myfunc(self):
        print("name : ",self.name)
        print("roll no : ",self.rollno)
s1=stu()
print(s1.myfunc())
# Out:
# name :  hamza
# roll no :  1669
# None

# %%
class Room:
    length = 0.0
    breadth = 0.0
    
    # method to calculate area
    def calculate_area(self):
        print("Area of Room =", self.length * self.breadth)

# create object of Room class
study_room = Room()

# assign values to all the attributes 
study_room.length = 42.5
study_room.breadth = 30.8

# access method inside class
study_room.calculate_area()
# Out:
# Area of Room = 1309.0

# %% [markdown]
# #### using constructors

# %% [markdown]
# __init__() is the constructor function that is called whenever a new object of that class is instantiated.

# %%
class bike():
    def __init__(self,name=""):
        self.name=name
b1=bike("honda")
print(b1.name)
# Out:
# honda

# %%
class person():
    def __init__(self,name,age):
        self.name=name
        self.age=age
p1=person("doe",36)
print(f"Name: {p1.name}, age: {p1.age} ")
# Out:
# Name: doe, age: 36

# %%
class stu:
 def __init__(self,name,rollno):#__init__ used for constructor
     print("name : ",name)
     print("roll no : ",rollno)
 def fun(self):
    print("i am registered in BSAI program")
s1=stu("hamza",1669)# automatically values printed
print(s1.fun())
# Out:
# name :  hamza
# roll no :  1669
# i am registered in BSAI program
# None

# %%
class stu:
    depart="AI"# class variable accessible to all
    def __init__(self,name,rollno):# constructor
        print("name : ",name)
        print("roll no : ",rollno)
        self.name=name
        self.rollno=rollno
    def det(self):
        print("-------------")
        print(self.name+"is nice")
s1=stu("john",1712)
print("department : -> ",s1.depart)
print(s1.det())
print("Name : -> ",s1.name)
print("Roll no: -> ",s1.rollno)
s1.rollno=1702
print("New roll no : -> ",s1.rollno)
# Out:
# name :  john
# roll no :  1712
# department : ->  AI
# -------------
# johnis nice
# None
# Name : ->  john
# Roll no: ->  1712
# New roll no : ->  1702

# %%
class stu:
 total=0
 def __init__(self,name,rollno):
    self.name=name
    self.rollno=rollno
    stu.total+=1
 def det(self):
    print("student's details-----")
    print("my name is :",self.name)
    print("my roll no is : ",self.rollno)
    print(self.name + " is studying")
s1=stu("hamza",1669)
s2=stu("bilal",1702)# second object
print(s1.det())# funcion call
print(s2.det())
print("number of students : ",stu.total)
# Out:
# student's details-----
# my name is : hamza
# my roll no is :  1669
# hamza is studying
# None
# student's details-----
# my name is : bilal
# my roll no is :  1702
# bilal is studying
# None
# number of students :  2

# %%
class Car():
 def __init__(self,make,mod,year):
    self.make = make
    self.mod = mod
    self.year = year
    self.odometer_reading = 0
 def get_descriptive_name(self):# get function
    long_name = str(self.year)+ ' '+self.make + ' ' + self.mod
    return long_name
c = Car('audi', 'a4', 2016)
name = c.get_descriptive_name()# calling get
print(name)
# Out:
# 2016 audi a4

# %%
class employee:
 
 def getdata(self):
    self.name=input("enter the name :")
    self.sal=int(input("enter the salary : "))
    self.tax=float(input("enter the tax percentage"))
 def salaftertax(self):
    self.newsal=self.tax*self.sal
    self.totalsal=self.sal-self.newsal
    print("new salary after tax is : ",self.totalsal)
 def taxupdate(self):
    self.tax=float(input("input new tax : "))
e1=employee()
e1.getdata()
e1.salaftertax()
e1.taxupdate()
e1.salaftertax()
# Out:
# enter the name :23
# enter the salary : 1500
# enter the tax percentage20
# new salary after tax is :  -28500.0
# input new tax : 15
# new salary after tax is :  -21000.0

# %% [markdown]
# ## Python Inheritance

# %% [markdown]
# Inheritance allows us to define a class that inherits all the methods and properties from another class.

# %% [markdown]
# Parent class is the class being inherited from, also called base class.

# %% [markdown]
# Child class is the class that inherits from another class, also called derived class.

# %%
class person:
    def __init__(self,fname,lname):
        self.fname=fname
        self.lname=lname
    def display(self):
        print(self.fname,self.lname)
class student(person):
    pass
p2=student("john","jones")
p1=person("jog","doe")
p1.display()
p2.display()
# Out:
# jog doe
# john jones

# %%
class animal():
    name=""
    def eat(self):
        print(" i can eat")
class dog(animal):
    def display(self):
        print("my name is : ",self.name)
labr=dog()
labr.name="kang"
labr.eat()
labr.display()
# Out:
#  i can eat
# my name is :  kang

# %% [markdown]
# some notes:

# %% [markdown]
# when you add __init__ to child class,then it will no longer inherit __init__ of parent class

# %% [markdown]
# to keep the inheritance of the parent's __init__() function, add a call to the parent's __init__() function:

# %%
# class Student(Person):
#   def __init__(self, fname, lname):
#     Person.__init__(self, fname, lname)# this how we inherit parent init in child

# %% [markdown]
# now we disuss inheritance types and along the way we will discuss some some important concepts

# %% [markdown]
# ##### single

# %%
class parent:# base class
 def func1(self):
    print("parent class")
class child(parent):# derived class
 def func2(self):
    print("i am child and can access parent attributes")
c=child()# object of derived,can access parent attributes
c.func1()
c.func2()
# Out:
# parent class
# i am child and can access parent attributes

# %% [markdown]
# ##### multiple

# %% [markdown]
# when a child inherits from more than one parent class ,eg mother father child

# %%
class A:
 def getx(self):
    self.x=int(input("enter the value of x : "))
class B:
 def gety(self):
    self.y=int(input("enter the value of y : "))
class C(A,B):
 def Sum(self):
    print("sum : ",self.x+self.y)
c=C()
c.getx()
c.gety()
c.Sum()

class mother:
    mothername="hanifa"
    def mom(self):
        print(self.mothername)
class father():
    fathername="tariq"
    def dad(self):
        print(self.fathername)
class son(mother,father):
    def parents(self):
        print("father : ",self.fathername)
        print("mother : ",self.mothername)
s=son()
s.dad()
s.mom()
s.parents()
# Out:
# enter the value of x : 4
# enter the value of y : 2
# sum :  6
# tariq
# hanifa
# father :  tariq
# mother :  hanifa

# %% [markdown]
# ##### multilevel

# %% [markdown]
# In multilevel inheritance, a child class inherits all its parent classes' properties.

# %% [markdown]
# The base class is the parent class of all sub-classes in multilevel inheritance.

# %% [markdown]
# Inheritance goes from parent to child. Parent classes cannot access the properties of the child class.

# %% [markdown]
# this is where we use our ;

# %%
# class Student(Person):
#   def __init__(self, fname, lname):
#     Person.__init__(self, fname, lname)# this how we inherit parent init in child

# %%
class grandf():
    def __init__(self,gname):
        self.gname=gname
class fath(grandf):
    def __init__(self,fname,gname):
        self.fname=fname
        grandf.__init__(self,gname)
class son(fath):
    def __init__(self,sname,fname,gname):
        self.sname=sname
        fath.__init__(self,fname,gname)
    def info(self):
        print("Name-->",self.sname)
        print("Father Name-->",self.fname)
        print("GrandFather Name-->",self.gname)
s1=son("hamza","tariq","ismail")
s1.info()
# Out:
# Name--> hamza
# Father Name--> tariq
# GrandFather Name--> ismail

# %%
class Polygon:
    # Initializing the number of sides
    def __init__(self, no_of_sides):
        self.n = no_of_sides
        self.sides = [0 for i in range(no_of_sides)]

    def inputSides(self):
        self.sides = [float(input("Enter side "+str(i+1)+" : ")) for i in range(self.n)]

    # method to display the length of each side of the polygon
    def dispSides(self):
        for i in range(self.n):
            print("Side",i+1,"is",self.sides[i])

class Triangle(Polygon):
    # Initializing the number of sides of the triangle to 3 by 
    # calling the __init__ method of the Polygon class
    def __init__(self):
        Polygon.__init__(self,3)

    def findArea(self):
        a, b, c = self.sides

        # calculate the semi-perimeter
        s = (a + b + c) / 2

        # Using Heron's formula to calculate the area of the triangle
        area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
        print('The area of the triangle is %0.2f' %area)

# Creating an instance of the Triangle class
t = Triangle()

# Prompting the user to enter the sides of the triangle
t.inputSides()

# Displaying the sides of the triangle
t.dispSides()

# Calculating and printing the area of the triangle
t.findArea()
# Out:
# Enter side 1 : 4
# Enter side 2 : 2
# Enter side 3 : 5
# Side 1 is 4.0
# Side 2 is 2.0
# Side 3 is 5.0
# The area of the triangle is 3.80

# %% [markdown]
# Create a child class Bus that will inherit all of the variables and methods of the Vehicle
# class

# %%
class vehicle:
 def __init__(self,name,speed,mileage):
    self.name=name
    self.speed=speed
    self.mileage=mileage
class bus(vehicle):
 def __init__(self,name,speed,mileage):
    vehicle.__init__(self,name,speed,mileage)
 def att(self):
    print("name : ",self.name)
    print("speed : ",self.speed)
    print("mileage : ",self.mileage)
b=bus("daewoo",120,125200)
b.att()
# Out:
# name :  daewoo
# speed :  120
# mileage :  125200

# %%
class base:
 def getdata(self):
    self.y=int(input("enter the value of y : "))
class derive1(base):
 def readdata(self):
    self.x=int(input("enter the value of x : "))
class derive2(derive1):
 def indata(self):
    self.z=int(input("enter the value of z: "))
 def prod(self):
    print("product result : ",self.x*self.y*self.z)
d=derive2()
d.getdata()
d.readdata()
d.indata()
d.prod()
# Out:
# enter the value of y : 4
# enter the value of x : 2
# enter the value of z: 4
# product result :  32

# %% [markdown]
# ##### heirarchical

# %% [markdown]
# Hierarchical Inheritance If multiple derived classes are created from the same base, this kind of Inheritance is known as hierarchical inheritance.

# %%
class A:
 def fun(self):
    print("i am base")
class B(A):
 def fun2(self):
    print("i am derived from A")
class C(A):
 def fun3(self):
    print("iam deived from A")
obj=B()
obj2=C()
obj.fun()
obj.fun2()
obj2.fun()
obj2.fun3()
# Out:
# i am base
# i am derived from A
# i am base
# iam deived from A

# %%
class A:
 def indata(self):
    self.x=int(input("enter value of x : "))
    self.y=int(input("enter the value of y : "))
class B(A):
 def prod(self):
    print("product : ",self.x*self.y)
class C(A):
 def Sum(self):
    print("sum : ",self.x+self.y)
obj1=B()
obj2=C()
obj1.indata()
obj1.prod()
obj2.indata()
obj2.Sum()
# Out:
# enter value of x : 4
# enter the value of y : 5
# product :  20
# enter value of x : 4
# enter the value of y : 5
# sum :  9

# %% [markdown]
# ![p2.png](attachment:p2.png)

# %% [markdown]
# ![p3.png](attachment:p3.png)

# %% [markdown]
# ![94.png](attachment:94.png)

# %% [markdown]
# ![p5.png](attachment:p5.png)

# %% [markdown]
# ### Method Overriding or ploymorphism in  Inheritance

# %% [markdown]
# In the previous examples, we see the object of the subclass can access the method of the superclass.

# %% [markdown]
# However, what if the same method is present in both the superclass and subclass?

# %% [markdown]
# In this case, the method in the subclass overrides the method in the superclass. This concept is known as method overriding in Python.

# %%
class Animal:

    # attributes and method of the parent class
    name = ""
    
    def eat(self):
        print("I can eat")

# inherit from Animal
class Dog(Animal):

    # override eat() method
    def eat(self):
        print("I like to eat bones")

# create an object of the subclass
labrador = Dog()

# call the eat() method on the labrador object
labrador.eat()
# Out:
# I like to eat bones

# %% [markdown]
# ### The super() Method in Python Inheritance

# %% [markdown]
# Previously we saw that the same method in the subclass overrides the method in the superclass.

# %% [markdown]
# However, if we need to access the superclass method from the subclass, we use the super() method.

# %%
class Animal:

    name = ""
    
    def eat(self):
        print("I can eat")

# inherit from Animal
class Dog(Animal):
    
    # override eat() method
    def eat(self):
        
        # call the eat() method of the superclass using super()
        super().eat()
        
        print("I like to eat bones")

# create an object of the subclass
labrador = Dog()

labrador.eat()
I#in the above example, the eat() method of the Dog subclass overrides the same method of the Animal superclass.
#Inside the Dog class, we have used super().eat()
# to call the eat() method of the Animal superclass from the Dog subclass.
#So, when we call the eat() method using the labrador object
#Both the overridden and the superclass version of the eat() method is executed.
# Out:
# I can eat
# I like to eat bones

# %% [markdown]
# ## Polymorphism

# %% [markdown]
# The word "polymorphism" means "many forms", and in programming it refers to methods/functions/operators with
# the same name that can be executed on many objects or classes.

# %% [markdown]
# #### Class Polymorphism

# %% [markdown]
# Polymorphism is often used in Class methods, where we can have multiple classes with the same method name.
#
# For example, say we have three classes: Car, Boat, and Plane, and they all have a method called move():

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car class
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat class
plane1 = Plane("Boeing", "747")     #Create a Plane class

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %% [markdown]
# #### Inheritance class polymorphism

# %% [markdown]
# What about classes with child classes with the same name? Can we use polymorphism there?
#
# Yes. If we use the example above and make a parent class called Vehicle, and make Car, Boat, Plane child classes of Vehicle, the child classes inherits the Vehicle methods, but can override them:

# %%
class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang") #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747") #Create a Plane object

for x in (car1, boat1, plane1):
  print(x.brand)
  print(x.model)
  x.move()
# Out:
# Ford
# Mustang
# Move!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!

# %% [markdown]
# ### Method overloading OR compile time polymorphism

# %% [markdown]
# Unlike many other popular object-oriented programming languages such as Java, Python doesn’t
# support compile-time polymorphism or method overloading. If a class or Python script has multiple
# methods with the same name, the method defined in the last will override the earlier one.

# %%
# method overlaoding example
def product(a, b):
    p = a * b
    print(p)
# Second product method
# Takes three argument and print their
# product
def product(a, b, c):
    p = a * b*c
    print(p)
# Uncommenting the below line shows an error
## product(4, 5)
# This line will call the second product method
product(4, 5, 5)
# Out:
# 100

# %%
print("-----------------------------------------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **SO THATS IT WITH OUR PYTHON TUTORIALS,NOW WE WILL DO 5 PROJECTS,AND THEN MOVE ONTO OUR MAIN GOAL TOWARDS DATA SCIENCE,
# WHERE WE WIL BE COVERING PYTHON PACKAGES OF NUMPY,PANDAS,SCIKIT,SKLEARN,MATPLOTLIB,AND OTHER INCLUDING OUR ML MODELS AND ALL,SO MANY MORE TO COME**

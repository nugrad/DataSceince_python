# %% [markdown]
# JSON is syntax used for storing and excahnging data

# %% [markdown]
# JSON is a text written with javascript object notation

# %% [markdown]
# working with JSON is just like working with Python dictionaries.

# %% [markdown]
# JSON data is not by default an array of Python dictionaries.
# But becomes just that once when loaded into Python. For that reason,
# we can treat JSON data as a list of dictionaries.

# %%
# # Python program to read
# # json file
  
  
# import json
  
# # Opening JSON file
# f = open('data.json')
  
# # returns JSON object as 
# # a dictionary
# data = json.load(f)
  
# # Iterating through the json
# # list
# for i in data['emp_details']:
#     print(i)
  
# # Closing file
# f.close()

# %% [markdown]
# ### convert from json to python

# %%
import json

# some JSON:
x =  '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30

# %% [markdown]
# ### convert from python to json

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %% [markdown]
# ![js.png](attachment:js.png)

# %%
import json

print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %% [markdown]
# ## structured example

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

print(json.dumps(x))
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %%
# we can format the result to make it easier for us
print(json.dumps(x, indent=4))
# Out:
# {
#     "name": "John",
#     "age": 30,
#     "married": true,
#     "divorced": false,
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "pets": null,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ]
# }

# %%
print(json.dumps(x, indent=4, separators=(". ", " = ")))
# Out:
# {
#     "name" = "John".
#     "age" = 30.
#     "married" = true.
#     "divorced" = false.
#     "children" = [
#         "Ann".
#         "Billy"
#     ].
#     "pets" = null.
#     "cars" = [
#         {
#             "model" = "BMW 230".
#             "mpg" = 27.5
#         }.
#         {
#             "model" = "Ford Edge".
#             "mpg" = 24.1
#         }
#     ]
# }

# %%
# we can order the results
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# {
#     "age": 30,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ],
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "divorced": false,
#     "married": true,
#     "name": "John",
#     "pets": null
# }

# %%
# data exploration
import pandas as pd
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 103            1       81             72             18       40  26.6
# 104            2       85             65              0        0  39.6
# 105            1      126             56             29      152  28.7
# 106            1       96            122              0        0  22.4
# 107            4      144             58             28      140  29.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 103                     0.283   24        0
# 104                     0.930   27        0
# 105                     0.801   21        0
# 106                     0.207   27        0
# 107                     0.287   37        0
#
# [108 rows x 9 columns]

# %%
df.shape
# Out:
# (108, 9)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df.iloc[1:4,:]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15],
#       dtype=int64)

# %%
# df['Glucose'].values()

# %%
df.mean()
# Out:
# Pregnancies                   4.370370
# Glucose                     118.194444
# BloodPressure                68.592593
# SkinThickness                19.120370
# Insulin                      71.916667
# BMI                          30.870370
# DiabetesPedigreeFunction      0.472815
# Age                          33.833333
# Outcome                       0.351852
# dtype: float64

# %%
df.median()
# Out:
# Pregnancies                   4.0000
# Glucose                     113.5000
# BloodPressure                72.0000
# SkinThickness                20.0000
# Insulin                       0.0000
# BMI                          31.3500
# DiabetesPedigreeFunction      0.3395
# Age                          31.0000
# Outcome                       0.0000
# dtype: float64

# %%
df.mode(axis=0)# for col
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0          1.0      100           66.0            0.0      0.0  0.0
# 1          NaN      103            NaN            NaN      NaN  NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                       NaN   NaN      NaN

# %%
from matplotlib import pyplot as plt
import seaborn as sns
correlations=df.corr()
sns.heatmap(data=correlations,square=True,cmap="bwr")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  <a list of 9 Text major ticklabel objects>)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count    108.00000  108.000000     108.000000     108.000000  108.000000
# mean       4.37037  118.194444      68.592593      19.120370   71.916667
# std        3.56932   33.399160      22.038215      16.289276  123.098860
# min        0.00000    0.000000       0.000000       0.000000    0.000000
# 25%        1.00000   98.500000      64.000000       0.000000    0.000000
# 50%        4.00000  113.500000      72.000000      20.000000    0.000000
# 75%        7.00000  139.500000      80.000000      32.000000  110.000000
# max       15.00000  197.000000     122.000000      60.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  108.000000                108.000000  108.000000  108.000000
# mean    30.870370                  0.472815   33.833333    0.351852
# std      9.412373                  0.371791   11.086322    0.479774
# min      0.000000                  0.102000   21.000000    0.000000
# 25%     25.300000                  0.248000   24.750000    0.000000
# 50%     31.350000                  0.339500   31.000000    0.000000
# 75%     37.225000                  0.586250   41.000000    1.000000
# max     49.700000                  2.288000   60.000000    1.000000

# %%
df[['Pregnancies','Age']].corr()
# Out:
#              Pregnancies       Age
# Pregnancies     1.000000  0.543135
# Age             0.543135  1.000000

# %% [markdown]
# ## DATA WRANGLING

# %% [markdown]
# Data wrangling is the process of removing errors and combining complex data sets to make them more accessible and easier to analyze. Due to the rapid expansion of the amount of data and data sources available today, storing and organizing large quantities of data for analysis is becoming increasingly necessary.

# %% [markdown]
# Data wrangling can be defined as the process of cleaning, organizing, and transforming raw data into the desired format for analysts to use for prompt decision-making. Also known as data cleaning or data munging, data wrangling enables businesses to tackle more complex data in less time, produce more accurate results, and make better decisions. The exact methods vary from project to project depending upon your data and the goal you are trying to achieve. More and more organizations are increasingly relying on data wrangling tools to make data ready for downstream analytics.

# %% [markdown]
# Benefits of Data Wrangling:
# Data wrangling helps to improve data usability as it converts data into a compatible format for the end system.
# It helps to quickly build data flows within an intuitive user interface and easily schedule and automate the data-flow process.
# Integrates various types of information and their sources (like databases, web services, files, etc.)
# Help users to process very large volumes of data easily and easily share data-flow techniques.

# %% [markdown]
# ![dt2.png](attachment:dt2.png)

# %% [markdown]
# ![dt3.png](attachment:dt3.png)

# %%
# missing value detection
df.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
# missing value treatment
#use df.fillna('')
# or use imputer using scikit learn
# remmeber mean imputer and median imputer only work for numerical values
# import numpy as np
# from sklearn.impute import SimpleImputer
# mean_imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
# mean_imputer=mean_imputer.fit(df)
# imputed_df=mean_imputer.transform(df.values)
# df=pd.DataFrame(data=imputed_df,columns=['Pregnancies','Glucose']).df.head(10)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#df = df.loc[(df.loc[:, 'Y1961':'Y2013']!=0).any(axis=1)]# method 1, drop rows with null values

# %%
#,method 2,filling zeros with mean value
# non_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
# for coloumn in non_zero:
#     diab[coloumn] = diab[coloumn].replace(0,np.NaN)
#     mean = int(diab[coloumn].mean(skipna = True))
#     diab[coloumn] = diab[coloumn].replace(np.NaN, mean)
#     print(diab[coloumn])

# %%
# outliers in dataset
# outlier detection
sns.boxplot(x=df['BloodPressure'])

# %%
# outlier treatment
# filter = (df['BloodPressure'].values > 100) & (df['BloodPressure'].values < 40)
filter = df['BloodPressure'].values <40

df_outlier_rem=df[filter]
df_outlier_rem
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7            10      115              0              0        0  35.3
# 15            7      100              0              0        0  30.0
# 18            1      103             30             38       83  43.3
# 49            7      105              0              0        0   0.0
# 60            2       84              0              0        0   0.0
# 78            0      131              0              0        0  43.2
# 81            2       74              0              0        0   0.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 7                      0.134   29        0
# 15                     0.484   32        1
# 18                     0.183   33        0
# 49                     0.305   24        0
# 60                     0.304   21        0
# 78                     0.270   26        1
# 81                     0.102   22        0

# %%
for column in df:
    plt.figure()
    df.boxplot([column])

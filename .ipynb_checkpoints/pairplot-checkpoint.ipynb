# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df=pd.read_csv('zoo.csv')
df
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
# user func for predator
def origin(num):
    if num==1:
        return 'shikari'
    else:
        return 'non shikari'
df['predator']=df['predator'].apply(origin)

# %%
df.head(15)
# Out:
#    animal_name  hair  feathers  eggs  milk  airborne  aquatic     predator  \
# 0     aardvark     1         0     0     1         0        0      shikari
# 1     antelope     1         0     0     1         0        0  non shikari
# 2         bass     0         0     1     0         0        1      shikari
# 3         bear     1         0     0     1         0        0      shikari
# 4         boar     1         0     0     1         0        0      shikari
# 5      buffalo     1         0     0     1         0        0  non shikari
# 6         calf     1         0     0     1         0        0  non shikari
# 7         carp     0         0     1     0         0        1  non shikari
# 8      catfish     0         0     1     0         0        1      shikari
# 9         cavy     1         0     0     1         0        0  non shikari
# 10     cheetah     1         0     0     1         0        0      shikari
# ...

# %%
sns.pairplot(df[['animal_name','toothed','predator']],hue='predator',height=4)

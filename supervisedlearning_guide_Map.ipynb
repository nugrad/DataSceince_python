# %% [markdown]
# # What is supervised learning

# %% [markdown]
# Supervised Learning is a type of machine learning used to train models from labeled training
# data. It allows you to predict output for future or unseen data.

# %% [markdown]
# Supervised learning uses a training set to teach models to yield the desired output. This training dataset includes inputs and correct outputs, which allow the model to learn over time. The algorithm measures its accuracy through the loss function, adjusting until the error has been sufficiently minimized.

# %% [markdown]
# ![sp1.png](attachment:sp1.png)

# %% [markdown]
# ![sp2.png](attachment:sp2.png)

# %% [markdown]
# ![sp3.png](attachment:sp3.png)

# %% [markdown]
# ![sp4.png](attachment:sp4.png)

# %% [markdown]
# # Understanding the Algorithm

# %% [markdown]
# ![sp5.png](attachment:sp5.png)

# %% [markdown]
# # flow of Algorithm

# %% [markdown]
# firstly there is training and testing part

# %% [markdown]
# ![sp6.png](attachment:sp6.png)

# %% [markdown]
# then there is prediction part

# %% [markdown]
# ![sp7.png](attachment:sp7.png)

# %% [markdown]
# ### Supervised learning can be broken into

# %% [markdown]
# ![sp8.png](attachment:sp8.png)

# %% [markdown]
# ### If target variable is categorical (classes), then use classification algorithm.

# %% [markdown]
# In other words, classification is applied when the output has finite and
# discreet values.
# Example: Predict the class of car given its features like horsepower,
# mileage, weight, colour, etc.
# The classifier will build its attributes based on these features.
# Analysis has three potential outcomes - Sedan, SUV, or Hatchback

# %% [markdown]
# see below

# %% [markdown]
# ![sp9.png](attachment:sp9.png)

# %% [markdown]
# ### If target variable is a continuous numeric variable (100–2000), then use a regression algorithm.

# %% [markdown]
# Example: Predict the price of a house given its sq. area, location,
# no of bedrooms, etc.
# A simple regression algorithm is given below
# y = w * x + b
# This shows relationship between price (y) and sq. area (x)
# where price is a number from a defined range.

# %% [markdown]
# ![sp10.png](attachment:sp10.png)

# %% [markdown]
# ### see the diagram below to get the things going

# %% [markdown]
# ![sp11.png](attachment:sp11.png)

# %% [markdown]
# ## Types of Classification and Regression Algorithms

# %% [markdown]
# ![sp12.png](attachment:sp12.png)

# %% [markdown]
# ![sp13.png](attachment:sp13.png)

# %% [markdown]
# #### by now i hope you have some idea what is supervised learning and algorithms associated with it,in my next notebook i will be covering Regression models

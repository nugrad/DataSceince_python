# %% [markdown]
# Pandas is a Python library.
#
# Pandas is used to analyze data.

# %% [markdown]
# ![pnd.png](attachment:pnd.png)

# %% [markdown]
# # Panda Intro

# %% [markdown]
# ## What is pandas ?

# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# ## Why use pandas ?

# %% [markdown]
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %% [markdown]
# ![pnd2.png](attachment:pnd2.png)

# %% [markdown]
# ## What Can Pandas Do ?

# %% [markdown]
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
# What is average value?
# Max value?
# Min value?

# %% [markdown]
# ## Pandas Series

# %% [markdown]
# series is like a column in a table

# %%
import pandas as pd
arr=[1,2,3]
sr=pd.Series(arr)
print(sr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# adding labels to the series

# %%
sr=pd.Series(arr,index=["lab1","lab2","lab3"])
print(sr)
# Out:
# lab1    1
# lab2    2
# lab3    3
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ## Pandas DataFrames

# %%
import pandas as pd
df1=['hamza','bilal','azaan']
df=pd.DataFrame(df1)
df
# Out:
#        0
# 0  hamza
# 1  bilal
# 2  azaan

# %%
import pandas as pd
data={
    'Name':["hamza","umer","jabbar"],
    'CGPA':[2.42,2.28,3.8]
}
df2=pd.DataFrame(data)
df2
# Out:
#      Name  CGPA
# 0   hamza  2.42
# 1    umer  2.28
# 2  jabbar  3.80

# %% [markdown]
# as we can see above,the dataframe is like an table with rows and columns

# %% [markdown]
# Pandas use the **loc** attribute to return one or more specified row(s)

# %%
#refer to the row index:
print(df2.loc[0])
# Out:
# Name    hamza
# CGPA     2.42
# Name: 0, dtype: object

# %%
print(df2.loc[[0, 1]])
# Out:
#     Name  CGPA
# 0  hamza  2.42
# 1   umer  2.28

# %% [markdown]
# we can also name our indexes

# %%
df2=pd.DataFrame(data,index=["1669","1677","1845"])
print(df2)
# Out:
#         Name  CGPA
# 1669   hamza  2.42
# 1677    umer  2.28
# 1845  jabbar  3.80

# %%
print(df2.loc["1677"])
# Out:
# Name    umer
# CGPA    2.28
# Name: 1677, dtype: object

# %% [markdown]
# ## Reading CSV files

# %% [markdown]
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %%
# make sure you have your your csv file in same folder as this code file,otherwise you have to provide path
import pandas as pd
data2=pd.read_csv('heart.csv')
data2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# if you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows,like it did above

# %% [markdown]
# ## Analyzing Data using pandas

# %% [markdown]
# we use our same dataset above

# %% [markdown]
# The **head()** method returns the headers and a specified number of rows, starting from the top.

# %%
data2.head()# by deafult gives 5,we can add value to get how many we want
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data2.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# There is also a **tail()** method for viewing the last rows of the DataFrame.

# %%
data2.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# The DataFrames object has a method called **info()**, that gives you more information about the data set.

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# dealing with COLUMNS

# %%
# renaming columns

# %%
data2.columns# before renaming
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data2.columns=['age','gender','chest_pain_type','resting_bp','cholestrol','fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'target'
    
]
data2.head()# changed column names
# Out:
#    age  gender  chest_pain_type  resting_bp  cholestrol  fasting_blood_sugar  \
# 0   52       1                0         125         212                    0
# 1   53       1                0         140         203                    1
# 2   70       1                0         145         174                    0
# 3   61       1                0         148         203                    0
# 4   62       0                0         138         294                    1
#
#    rest_ecg  max_heart_rate_achieved  exercise_induced_angina  st_depression  \
# 0         1                      168                        0            1.0
# 1         0                      155                        1            3.1
# 2         1                      125                        1            2.6
# 3         1                      161                        0            0.0
# 4         1                      106                        0            1.9
#
# ...

# %%
# renaming specific column

# %%
d1=data2.rename(columns={'rest_ecg':'resting electrocardiographic result'})
d1.head()
# Out:
#    age  gender  chest_pain_type  resting_bp  cholestrol  fasting_blood_sugar  \
# 0   52       1                0         125         212                    0
# 1   53       1                0         140         203                    1
# 2   70       1                0         145         174                    0
# 3   61       1                0         148         203                    0
# 4   62       0                0         138         294                    1
#
#    resting electrocardiographic result  max_heart_rate_achieved  \
# 0                                    1                      168
# 1                                    0                      155
# 2                                    1                      125
# 3                                    1                      161
# 4                                    1                      106
#
#    exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# ...

# %%
# adding columns

# %%
d2=data2.head(10)
names = ['Ali', 'Salman', 'Sohail', 'Mohsin','Waqas','Zeshan','Babar','John','Elon','Michael']
d2.insert(0,'name',names)
d2
# Out:
#       name  age  gender  chest_pain_type  resting_bp  cholestrol  \
# 0      Ali   52       1                0         125         212
# 1   Salman   53       1                0         140         203
# 2   Sohail   70       1                0         145         174
# 3   Mohsin   61       1                0         148         203
# 4    Waqas   62       0                0         138         294
# 5   Zeshan   58       0                0         100         248
# 6    Babar   58       1                0         114         318
# 7     John   55       1                0         160         289
# 8     Elon   46       1                0         120         249
# 9  Michael   54       1                0         122         286
#
#    fasting_blood_sugar  rest_ecg  max_heart_rate_achieved  \
# 0                    0         1                      168
# 1                    1         0                      155
# 2                    0         1                      125
# ...

# %%
#droping columns
#df. drop("A", axis = 1) , it will drop a whole column.
#“axis 0” represents rows

# %%
data2.drop(['rest_ecg'], axis = 1, inplace = True)
data2
# Out:
#       age  gender  chest_pain_type  resting_bp  cholestrol  \
# 0      52       1                0         125         212
# 1      53       1                0         140         203
# 2      70       1                0         145         174
# 3      61       1                0         148         203
# 4      62       0                0         138         294
# ...   ...     ...              ...         ...         ...
# 1020   59       1                1         140         221
# 1021   60       1                0         125         258
# 1022   47       1                0         110         275
# 1023   50       0                0         110         254
# 1024   54       1                0         120         188
#
#       fasting_blood_sugar  max_heart_rate_achieved  exercise_induced_angina  \
# 0                       0                      168                        0
# 1                       1                      155                        1
# ...

# %% [markdown]
# dealing with ROWS

# %%
import pandas as pd
data3=pd.read_csv('diabetes.csv')
data3.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# adding row

# %%
new_rows={'Pregnancies':7,'Glucose':190,'BloodPressure':99,'SkinThickness':12,'Insulin':0,'DiabetesPedigreeFunction':0.962,
         'Age':42,'Outcome':1}
#ignore_index by-default=False. If True, index values are not used along concatenation axis and the resulting axis will be labeled 0,1,..,n-1.
#Cannot append dictionary if ignore_index=False
data3=data3.append(new_rows,ignore_index=True)
data3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9.0    140.0           71.0           32.0      1.0  26.5
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 106          1.0     96.0          122.0            0.0      0.0  22.4
# 107          4.0    144.0           58.0           28.0    140.0  29.5
# 108          7.0    190.0           99.0            NaN      0.0   NaN
# 109          7.0    190.0           99.0            NaN      0.0   NaN
# 110          7.0    190.0           99.0           12.0      0.0   NaN
#
#      DiabetesPedigreeFunction   Age  Outcome  Skin Thickness
# ...

# %%
# add row at specific index using loc

# %%
data3.loc[0] = [9,140,71,32,1,26.5,0.005,63,1,13]
data3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9.0    140.0           71.0           32.0      1.0  26.5
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 106          1.0     96.0          122.0            0.0      0.0  22.4
# 107          4.0    144.0           58.0           28.0    140.0  29.5
# 108          7.0    190.0           99.0            NaN      0.0   NaN
# 109          7.0    190.0           99.0            NaN      0.0   NaN
# 110          7.0    190.0           99.0           12.0      0.0   NaN
#
#      DiabetesPedigreeFunction   Age  Outcome  Skin Thickness
# ...

# %%
#select rows faster
data3.iloc[0] # first row of data frame (

# data3.iloc[-1] # last row of data frame
# Out:
# Pregnancies                   9.000
# Glucose                     140.000
# BloodPressure                71.000
# SkinThickness                32.000
# Insulin                       1.000
# BMI                          26.500
# DiabetesPedigreeFunction      0.005
# Age                          63.000
# Outcome                       1.000
# Skin Thickness               13.000
# Name: 0, dtype: float64

# %%
data3.iloc[1] # second row of data frame
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Skin Thickness                 NaN
# Name: 1, dtype: float64

# %%
data3.iloc[-1] # last row of data frame
# Out:
# Pregnancies                   7.000
# Glucose                     190.000
# BloodPressure                99.000
# SkinThickness                12.000
# Insulin                       0.000
# BMI                             NaN
# DiabetesPedigreeFunction      0.962
# Age                          42.000
# Outcome                       1.000
# Skin Thickness                  NaN
# Name: 110, dtype: float64

# %% [markdown]
# ## Some more Setting

# %%
import pandas as pd
data4=pd.read_csv('winequality-red.csv')
data4.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data4[['fixed acidity','citric acid']]
# Out:
#       fixed acidity  citric acid
# 0               7.4         0.00
# 1               7.8         0.00
# 2               7.8         0.04
# 3              11.2         0.56
# 4               7.4         0.00
# ...             ...          ...
# 1594            6.2         0.08
# 1595            5.9         0.10
# 1596            6.3         0.13
# 1597            5.9         0.12
# 1598            6.0         0.47
#
# [1599 rows x 2 columns]

# %%
# setting the name of indexex

# %%
data4=data4.rename_axis('vinesample')
data4
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 0                     7.4             0.700         0.00             1.9
# 1                     7.8             0.880         0.00             2.6
# 2                     7.8             0.760         0.04             2.3
# 3                    11.2             0.280         0.56             1.9
# 4                     7.4             0.700         0.00             1.9
# ...                   ...               ...          ...             ...
# 1594                  6.2             0.600         0.08             2.0
# 1595                  5.9             0.550         0.10             2.2
# 1596                  6.3             0.510         0.13             2.3
# 1597                  5.9             0.645         0.12             2.0
# 1598                  6.0             0.310         0.47             3.6
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
data4.iloc[0][0]# gives values for columns like value of first column of firstrow
# Out:
# 7.4

# %%
# we can sort values for specific columns

# %%
data4.sort_values('fixed acidity',inplace=True)
data4
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 45                    4.6             0.520         0.15             2.1
# 95                    4.7             0.600         0.17             2.3
# 821                   4.9             0.420         0.00             2.1
# 588                   5.0             0.420         0.24             2.0
# 94                    5.0             1.020         0.04             1.4
# ...                   ...               ...          ...             ...
# 555                  15.5             0.645         0.49             4.2
# 554                  15.5             0.645         0.49             4.2
# 442                  15.6             0.685         0.76             3.7
# 557                  15.6             0.645         0.49             4.2
# 652                  15.9             0.360         0.65             7.5
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
# change values

# %%
data4.at[45,'fixed acidity'] = 4.2# change values
# 45 shows index number
data4
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 45.0                  4.2             0.520         0.15             2.1
# 95.0                  4.7             0.600         0.17             2.3
# 821.0                 4.9             0.420         0.00             2.1
# 588.0                 5.0             0.420         0.24             2.0
# 94.0                  5.0             1.020         0.04             1.4
# ...                   ...               ...          ...             ...
# 554.0                15.5             0.645         0.49             4.2
# 442.0                15.6             0.685         0.76             3.7
# 557.0                15.6             0.645         0.49             4.2
# 652.0                15.9             0.360         0.65             7.5
# 4.6                   4.2               NaN          NaN             NaN
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %% [markdown]
# #### concatenation

# %%
# concatenating dataset3,4
res=pd.concat([data3,data4],ignore_index=True)
dr1=res.head(10)
dr1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          9.0    140.0           71.0           32.0      1.0  26.5
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
# 5          5.0    116.0           74.0            0.0      0.0  25.6
# 6          3.0     78.0           50.0           32.0     88.0  31.0
# 7         10.0    115.0            0.0            0.0      0.0  35.3
# 8          2.0    197.0           70.0           45.0    543.0  30.5
# 9          8.0    125.0           96.0            0.0      0.0   0.0
#
#    DiabetesPedigreeFunction   Age  Outcome  Skin Thickness  ...  citric acid  \
# 0                     0.005  63.0      1.0            13.0  ...          NaN
# ...

# %%
# concat columns

res2=pd.concat([res,data4],axis=1,ignore_index=False)
dr2=res2.head()
dr2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0.0          9.0    140.0           71.0           32.0      1.0  26.5
# 1.0          1.0     85.0           66.0           29.0      0.0  26.6
# 2.0          8.0    183.0           64.0            0.0      0.0  23.3
# 3.0          1.0     89.0           66.0           23.0     94.0  28.1
# 4.0          0.0    137.0           40.0           35.0    168.0  43.1
#
#      DiabetesPedigreeFunction   Age  Outcome  Skin Thickness  ...  \
# 0.0                     0.005  63.0      1.0            13.0  ...
# 1.0                     0.351  31.0      0.0             NaN  ...
# 2.0                     0.672  32.0      1.0             NaN  ...
# 3.0                     0.167  21.0      0.0             NaN  ...
# 4.0                     2.288  33.0      1.0             NaN  ...
#
#      citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0.0         0.00             1.9      0.076                 11.0
# ...

# %% [markdown]
# #### Slicing

# %% [markdown]
# we  use will our diabetes data data,dataset3

# %%
data3.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          9.0    140.0           71.0           32.0      1.0  26.5
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
# 5          5.0    116.0           74.0            0.0      0.0  25.6
# 6          3.0     78.0           50.0           32.0     88.0  31.0
# 7         10.0    115.0            0.0            0.0      0.0  35.3
# 8          2.0    197.0           70.0           45.0    543.0  30.5
# 9          8.0    125.0           96.0            0.0      0.0   0.0
#
#    DiabetesPedigreeFunction   Age  Outcome  Skin Thickness
# 0                     0.005  63.0      1.0            13.0
# 1                     0.351  31.0      0.0             NaN
# ...

# %%
data3.iloc[0:2,:]# select rows with index 0,1 not including 2,all select all columns
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          9.0    140.0           71.0           32.0      1.0  26.5
# 1          1.0     85.0           66.0           29.0      0.0  26.6
#
#    DiabetesPedigreeFunction   Age  Outcome  Skin Thickness
# 0                     0.005  63.0      1.0            13.0
# 1                     0.351  31.0      0.0             NaN

# %%
data3.iloc[:,1:3]# all rows,column index 1-3 not including 3
# Out:
#      Glucose  BloodPressure
# 0      140.0           71.0
# 1       85.0           66.0
# 2      183.0           64.0
# 3       89.0           66.0
# 4      137.0           40.0
# ..       ...            ...
# 106     96.0          122.0
# 107    144.0           58.0
# 108    190.0           99.0
# 109    190.0           99.0
# 110    190.0           99.0
#
# [111 rows x 2 columns]

# %%
data3.iloc[1:2,1:3]
# Out:
#    Glucose  BloodPressure
# 1     85.0           66.0

# %%
data4.iloc[: , :]
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 45.0                  4.2             0.520         0.15             2.1
# 95.0                  4.7             0.600         0.17             2.3
# 821.0                 4.9             0.420         0.00             2.1
# 588.0                 5.0             0.420         0.24             2.0
# 94.0                  5.0             1.020         0.04             1.4
# ...                   ...               ...          ...             ...
# 554.0                15.5             0.645         0.49             4.2
# 442.0                15.6             0.685         0.76             3.7
# 557.0                15.6             0.645         0.49             4.2
# 652.0                15.9             0.360         0.65             7.5
# 4.6                   4.2               NaN          NaN             NaN
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
data4.iloc[2: , :5]
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 821.0                 4.9             0.420         0.00             2.1
# 588.0                 5.0             0.420         0.24             2.0
# 94.0                  5.0             1.020         0.04             1.4
# 553.0                 5.0             1.040         0.24             1.6
# 1270.0                5.0             0.380         0.01             1.6
# ...                   ...               ...          ...             ...
# 554.0                15.5             0.645         0.49             4.2
# 442.0                15.6             0.685         0.76             3.7
# 557.0                15.6             0.645         0.49             4.2
# 652.0                15.9             0.360         0.65             7.5
# 4.6                   4.2               NaN          NaN             NaN
#
#             chlorides
# vinesample
# 821.0           0.048
# ...

# %%
data4.iloc[0:5:2 , 2:4:2]      #iloc[starting row:ending row:stepSize , starting column:ending column:stepSize]
# Out:
#             citric acid
# vinesample
# 45.0               0.15
# 821.0              0.00
# 94.0               0.04

# %% [markdown]
# #### merging

# %%
import pandas as pd
# Define a dictionary containing employee data 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
 'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
 'Age':[27, 24, 22, 32],} 
 
# Define a dictionary containing employee data 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
 'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
 'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data1)
# Convert the dictionary into DataFrame 
df1 = pd.DataFrame(data2) 
 
print(df, "\n\n", df1) 
# using .merge() function
res = pd.merge(df, df1, on='key')
res
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#
#    key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
import pandas as pd
# Define a dictionary containing employee data 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
 'key1': ['K0', 'K1', 'K0', 'K1'],
 'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
 'Age':[27, 24, 22, 32],} 
 
# Define a dictionary containing employee data 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
 'key1': ['K0', 'K0', 'K0', 'K0'],
 'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
 'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data1)
# Convert the dictionary into DataFrame 
df1 = pd.DataFrame(data2)
# merging dataframe using multiple keys
res1 = pd.merge(df, df1, on=['key', 'key1'])
res1
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
res2 = pd.merge(df, df1, how='outer', on=['key', 'key1'])
res2
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K1  Princi  24.0        NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K1    Anuj  32.0        NaN           NaN
# 4  K1   K0     NaN   NaN     Kanpur           B.A
# 5  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# getting intersection of keys
res3 = pd.merge(df, df1, how='inner', on=['key', 'key1'])
res3
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %% [markdown]
# ## Working with missing data

# %% [markdown]
# we use dataset 4

# %%
# using isnull() function 
data4.isnull()#Finds NULL values
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 45.0                False             False        False           False
# 95.0                False             False        False           False
# 821.0               False             False        False           False
# 588.0               False             False        False           False
# 94.0                False             False        False           False
# ...                   ...               ...          ...             ...
# 554.0               False             False        False           False
# 442.0               False             False        False           False
# 557.0               False             False        False           False
# 652.0               False             False        False           False
# 4.6                 False              True         True            True
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
# filling missing value using fillna() 
data4.fillna(0)
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# vinesample
# 45.0                  4.2             0.520         0.15             2.1
# 95.0                  4.7             0.600         0.17             2.3
# 821.0                 4.9             0.420         0.00             2.1
# 588.0                 5.0             0.420         0.24             2.0
# 94.0                  5.0             1.020         0.04             1.4
# ...                   ...               ...          ...             ...
# 554.0                15.5             0.645         0.49             4.2
# 442.0                15.6             0.685         0.76             3.7
# 557.0                15.6             0.645         0.49             4.2
# 652.0                15.9             0.360         0.65             7.5
# 4.6                   4.2             0.000         0.00             0.0
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
# drop missing value
data4.dropna(axis=1)#Drops all rows that contains NULL values
# Out:
#             fixed acidity
# vinesample
# 45.0                  4.2
# 95.0                  4.7
# 821.0                 4.9
# 588.0                 5.0
# 94.0                  5.0
# ...                   ...
# 554.0                15.5
# 442.0                15.6
# 557.0                15.6
# 652.0                15.9
# 4.6                   4.2
#
# [1600 rows x 1 columns]

# %% [markdown]
# #### Describe()

# %% [markdown]
# The describe() method returns description of the data in the DataFrame.
#
# If the DataFrame contains numerical data, the description contains these information for each column:
#
# count - The number of not-empty values.
# mean - The average (mean) value.
# std - The standard deviation.
# min - the minimum value.
# 25% - The 25% percentile*.
# 50% - The 50% percentile*.
# 75% - The 75% percentile*.
# max - the maximum value.

# %%
data4.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1600.000000       1599.000000  1599.000000     1599.000000
# mean        8.316812          0.527821     0.270976        2.538806
# std         1.744158          0.179060     0.194801        1.409928
# min         4.200000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Cleaning Data

# %%
import pandas as pd
data5=pd.read_csv('Social_Network_Ads.csv')
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
#drop columns having all values as null values
data5 = data5.dropna(axis=1,how='all')
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#replacing male and female with 0 and 1
data5['Gender'].replace({'Female' : 0, 'Male' : 1}, inplace = True)
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
#converting salary column to integer type
data5['EstimatedSalary']=data5.EstimatedSalary.astype('float64')
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19          19000.0          0
# 1    15810944       1   35          20000.0          0
# 2    15668575       0   26          43000.0          0
# 3    15603246       0   27          57000.0          0
# 4    15804002       1   19          76000.0          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46          41000.0          1
# 396  15706071       1   51          23000.0          1
# 397  15654296       0   50          20000.0          1
# 398  15755018       1   36          33000.0          0
# 399  15594041       0   49          36000.0          1
#
# [400 rows x 5 columns]

# %%
#The fillna() method allows us to replace empty cells with a value:
data5.fillna(130, inplace = True)
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19          19000.0          0
# 1    15810944       1   35          20000.0          0
# 2    15668575       0   26          43000.0          0
# 3    15603246       0   27          57000.0          0
# 4    15804002       1   19          76000.0          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46          41000.0          1
# 396  15706071       1   51          23000.0          1
# 397  15654296       0   50          20000.0          1
# 398  15755018       1   36          33000.0          0
# 399  15594041       0   49          36000.0          1
#
# [400 rows x 5 columns]

# %%
#The duplicated() method returns a Boolean values for each row:
#Returns True for every row that is a duplicate, othwerwise False:
print(data5.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Length: 400, dtype: bool

# %%
#To remove duplicates, use the drop_duplicates() method.
data5.drop_duplicates(inplace = True)
data5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19          19000.0          0
# 1    15810944       1   35          20000.0          0
# 2    15668575       0   26          43000.0          0
# 3    15603246       0   27          57000.0          0
# 4    15804002       1   19          76000.0          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46          41000.0          1
# 396  15706071       1   51          23000.0          1
# 397  15654296       0   50          20000.0          1
# 398  15755018       1   36          33000.0          0
# 399  15594041       0   49          36000.0          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ## Pandas Plotting

# %%
import pandas as pd
data6=pd.read_csv('data.csv')
data6
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
data6.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
import matplotlib.pyplot as plt
data6.plot()

plt.show()

# %%
data6.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %%
data6.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')

plt.show()

# %% [markdown]
# Use the kind argument to specify that you want a histogram:
#
# kind = 'hist'
#
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?
#
# In the example below we will use the "Duration" column to create the histogram

# %%
data6["Duration"].plot(kind = 'hist')

# %% [markdown]
# ### Playing with Data Frames

# %%
import pandas as pd
rd=pd.read_csv('employees.csv')
rd
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
rd.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
rd.iloc[0]
# Out:
# First Name             Douglas
# Gender                    Male
# Start Date            8/6/1993
# Last Login Time       12:42 PM
# Salary                   97308
# Bonus %                  6.945
# Senior Management         True
# Team                 Marketing
# Name: 0, dtype: object

# %%
rd2=pd.read_csv('employees.csv')
rd2=rd2[rd2['Team']=='Marketing']
rd2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 21     Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 26       Craig    Male   2/27/2000         7:45 AM   37598    7.757
# 43     Marilyn  Female   12/7/1980         3:16 AM   73524    5.207
# 62         NaN  Female   6/12/2007         5:25 PM   58112   19.414
# ..         ...     ...         ...             ...     ...      ...
# 942       Lori  Female  11/20/2015         1:15 PM   75498    6.537
# 947        NaN    Male   7/30/2012         3:07 PM  107351    5.329
# 986      Donna  Female  11/26/1982         7:04 AM   82871   17.999
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing
# ...

# %% [markdown]
# ### Multindexing in Python

# %%
import pandas as pd
rd3=pd.read_csv('employees.csv')
rd3.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
rd3.set_index(['Team','Salary'],inplace=True)

# %%
rd3.loc['Finance']
# Out:
#        First Name  Gender  Start Date Last Login Time  Bonus %  \
# Salary
# 130590      Maria  Female   4/23/1993        11:17 AM   11.858
# 138705      Jerry    Male    3/4/2005         1:00 PM    9.340
# 45906         NaN  Female   7/20/2015        10:43 AM   11.598
# 41426    Kimberly  Female   1/14/1999         7:13 AM   14.543
# 114796      Bruce    Male  11/28/2009        10:47 PM    6.796
# ...           ...     ...         ...             ...      ...
# 137144  Elizabeth  Female   7/27/1998        11:12 AM   10.081
# 119667        Joe    Male   1/19/1980         4:06 PM    1.148
# 136709     Gloria  Female   12/8/2014         5:08 AM   10.331
# 112769    Anthony    Male  10/16/2011         8:35 AM   11.625
# 42392     Phillip    Male   1/31/1984         6:30 AM   19.675
#
#        Senior Management
# Salary
# 130590             False
# 138705              True
# 45906                NaN
# 41426               True
# 114796             False
# ...                  ...
# ...

# %%
rd3.loc['Finance'].loc[130590]
# Out:
# First Name               Maria
# Gender                  Female
# Start Date           4/23/1993
# Last Login Time       11:17 AM
# Bonus %                 11.858
# Senior Management        False
# Name: 130590, dtype: object

# %%
import pandas as pd
test=pd.read_csv('employees.csv')
test.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
test.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
test.plot()

# %%
test['Salary'].plot(legend=True)

# %%
# test.plot(x='Salary',y='Bonus%',kind='scatter',legend=True)

# %%
# test['Salary'].plot(kind='box',title='box plot')
